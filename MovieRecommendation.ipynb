# %% [markdown]
#  MOVIE RECOMMENDATION ENGINE

# %%
import pandas as pd
import numpy as np
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity

# %%
ratings = pd.read_csv("Amazon - Movies and TV Ratings.csv") #Reading the file
ratings = ratings.drop(['user_id'], axis=1)
ratings.describe()
# Out:
#        Movie1  Movie2  Movie3  Movie4     Movie5  Movie6  Movie7  Movie8  \
# count     1.0     1.0     1.0     2.0  29.000000     1.0     1.0     1.0
# mean      5.0     5.0     2.0     5.0   4.103448     4.0     5.0     5.0
# std       NaN     NaN     NaN     0.0   1.496301     NaN     NaN     NaN
# min       5.0     5.0     2.0     5.0   1.000000     4.0     5.0     5.0
# 25%       5.0     5.0     2.0     5.0   4.000000     4.0     5.0     5.0
# 50%       5.0     5.0     2.0     5.0   5.000000     4.0     5.0     5.0
# 75%       5.0     5.0     2.0     5.0   5.000000     4.0     5.0     5.0
# max       5.0     5.0     2.0     5.0   5.000000     4.0     5.0     5.0
#
#        Movie9  Movie10  ...  Movie197  Movie198  Movie199  Movie200  Movie201  \
# count     1.0      1.0  ...  5.000000       2.0       1.0  8.000000  3.000000
# mean      5.0      5.0  ...  3.800000       5.0       5.0  4.625000  4.333333
# ...

# %%
ratings = ratings.fillna(0)
df.head()
# Out:
#           Movie1    Movie2    Movie3    Movie4    Movie5    Movie6    Movie7  \
# Movie1  1.000000  1.000000 -0.000206 -0.000292 -0.001049 -0.000206 -0.000206
# Movie2  1.000000  1.000000 -0.000206 -0.000292 -0.001049 -0.000206 -0.000206
# Movie3 -0.000206 -0.000206  1.000000 -0.000292 -0.001049 -0.000206 -0.000206
# Movie4 -0.000292 -0.000292 -0.000292  1.000000 -0.001483 -0.000292 -0.000292
# Movie5 -0.001049 -0.001049 -0.001049 -0.001483  1.000000 -0.001049 -0.001049
#
#           Movie8    Movie9   Movie10  ...  Movie197  Movie198  Movie199  \
# Movie1 -0.000206 -0.000206 -0.000206  ... -0.000430 -0.000292 -0.000206
# Movie2 -0.000206 -0.000206 -0.000206  ... -0.000430 -0.000292 -0.000206
# Movie3 -0.000206 -0.000206 -0.000206  ... -0.000430 -0.000292 -0.000206
# Movie4 -0.000292 -0.000292 -0.000292  ... -0.000609 -0.000413 -0.000292
# Movie5 -0.001049 -0.001049 -0.001049  ... -0.002188 -0.001483 -0.001049
#
# ...

# %%
#Standarizing the ratings of all users 
def standardize(row):
    new_row =(row - row.mean())/(row.max() - row.min())
    return new_row

df_std = ratings.apply(standardize)
df_std
# Out:
#         Movie1    Movie2    Movie3    Movie4    Movie5    Movie6    Movie7  \
# 0     0.999794  0.999794 -0.000206 -0.000413 -0.004909 -0.000206 -0.000206
# 1    -0.000206 -0.000206  0.999794 -0.000413 -0.004909 -0.000206 -0.000206
# 2    -0.000206 -0.000206 -0.000206  0.999587 -0.004909 -0.000206 -0.000206
# 3    -0.000206 -0.000206 -0.000206  0.999587 -0.004909 -0.000206 -0.000206
# 4    -0.000206 -0.000206 -0.000206 -0.000413  0.995091 -0.000206 -0.000206
# ...        ...       ...       ...       ...       ...       ...       ...
# 4843 -0.000206 -0.000206 -0.000206 -0.000413 -0.004909 -0.000206 -0.000206
# 4844 -0.000206 -0.000206 -0.000206 -0.000413 -0.004909 -0.000206 -0.000206
# 4845 -0.000206 -0.000206 -0.000206 -0.000413 -0.004909 -0.000206 -0.000206
# 4846 -0.000206 -0.000206 -0.000206 -0.000413 -0.004909 -0.000206 -0.000206
# 4847 -0.000206 -0.000206 -0.000206 -0.000413 -0.004909 -0.000206 -0.000206
#
# ...

# %%
#using cosine similarity to calculate similarity row-wise
item_similarity = cosine_similarity(df_std.T) #taking the transpose
print(item_similarity)
# Out:
# [[ 1.00000000e+00  1.00000000e+00 -2.06313183e-04 ... -5.59140306e-04
#   -1.20232978e-03 -7.43703762e-04]
#  [ 1.00000000e+00  1.00000000e+00 -2.06313183e-04 ... -5.59140306e-04
#   -1.20232978e-03 -7.43703762e-04]
#  [-2.06313183e-04 -2.06313183e-04  1.00000000e+00 ... -5.59140306e-04
#   -1.20232978e-03 -7.43703762e-04]
#  ...
#  [-5.59140306e-04 -5.59140306e-04 -5.59140306e-04 ...  1.00000000e+00
#   -3.25849773e-03 -2.01555103e-03]
#  [-1.20232978e-03 -1.20232978e-03 -1.20232978e-03 ... -3.25849773e-03
#    1.00000000e+00 -4.33407679e-03]
#  [-7.43703762e-04 -7.43703762e-04 -7.43703762e-04 ... -2.01555103e-03
#   -4.33407679e-03  1.00000000e+00]]

# %%
#convertinf into dataframe from the above numoy array
df = pd.DataFrame(item_similarity,index =ratings.columns,columns = ratings.columns )
df
# Out:
#             Movie1    Movie2    Movie3    Movie4    Movie5    Movie6  \
# Movie1    1.000000  1.000000 -0.000206 -0.000292 -0.001049 -0.000206
# Movie2    1.000000  1.000000 -0.000206 -0.000292 -0.001049 -0.000206
# Movie3   -0.000206 -0.000206  1.000000 -0.000292 -0.001049 -0.000206
# Movie4   -0.000292 -0.000292 -0.000292  1.000000 -0.001483 -0.000292
# Movie5   -0.001049 -0.001049 -0.001049 -0.001483  1.000000 -0.001049
# ...            ...       ...       ...       ...       ...       ...
# Movie202 -0.000478 -0.000478 -0.000478 -0.000676 -0.002430 -0.000478
# Movie203 -0.000206 -0.000206 -0.000206 -0.000292 -0.001049 -0.000206
# Movie204 -0.000559 -0.000559 -0.000559 -0.000791 -0.002842 -0.000559
# Movie205 -0.001202 -0.001202 -0.001202 -0.001701 -0.006111 -0.001202
# Movie206 -0.000744 -0.000744 -0.000744 -0.001052 -0.003780 -0.000744
#
#             Movie7    Movie8    Movie9   Movie10  ...  Movie197  Movie198  \
# ...

# %%
#making recommendations

def get_similar_movies(name,rating):
    similar_score = df[name]*rating
    similar_score = similar_score.sort_values(ascending=False)
    return similar_score
print(get_similar_movies("Movie5",4))
# Out:
# Movie5      4.000000
# Movie203   -0.004194
# Movie199   -0.004194
# Movie195   -0.004194
# Movie187   -0.004194
#               ...
# Movie29    -0.066436
# Movie103   -0.069320
# Movie16    -0.076376
# Movie140   -0.106483
# Movie127   -0.251695
# Name: Movie5, Length: 206, dtype: float64
